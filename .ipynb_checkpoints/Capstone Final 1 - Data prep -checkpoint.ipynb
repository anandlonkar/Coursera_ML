# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# %%
CLIENT_ID = '0ICBHEHTFNB1KOUD5TI3Z14DZUD1R5LXFXGL4F3SMNFDZRQ5' # your Foursquare ID
CLIENT_SECRET = 'SGBN541VKULWFT2PKKVVL3EEV01GTYX1TQZJGW5HQ41MHRCL' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 0ICBHEHTFNB1KOUD5TI3Z14DZUD1R5LXFXGL4F3SMNFDZRQ5
# CLIENT_SECRET:SGBN541VKULWFT2PKKVVL3EEV01GTYX1TQZJGW5HQ41MHRCL

# %%
address = '102 North End Ave, New York, NY'

latitude = 33.163130  
longitude = -96.790193
print(latitude, longitude)
# Out:
# 33.16313 -96.790193

# %%
search_query = 'Italian'
radius = 10000
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=0ICBHEHTFNB1KOUD5TI3Z14DZUD1R5LXFXGL4F3SMNFDZRQ5&client_secret=SGBN541VKULWFT2PKKVVL3EEV01GTYX1TQZJGW5HQ41MHRCL&ll=33.16313,-96.790193&v=20180604&radius=10000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7d67986a60714c844a842c'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Frisco',
#   'headerFullLocation': 'Frisco',
#   'headerLocationGranularity': 'city',
#   'totalResults': 234,
#   'suggestedBounds': {'ne': {'lat': 33.25313009000009,
#     'lng': -96.68288171217714},
#    'sw': {'lat': 33.07312990999991, 'lng': -96.89750428782287}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53653eca498e7f014d89e43c',
#        'name': 'Hutchins BBQ',
#        'location': {'address': '9225 Preston Rd',
#         'lat': 33.15459315172794,
#         'lng': -96.80469570495437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15459315172794,
#           'lng': -96.80469570495437}],
#         'distance': 1652,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9225 Preston Rd',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53653eca498e7f014d89e43c-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589a532caf5c141e6cca4711',
#        'name': 'ILoveKickboxing.com - Frisco, TX',
#        'location': {'address': '8845 Gary Burns Dr #150',
#         'lat': 33.14925596092092,
#         'lng': -96.80598397303409,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.14925596092092,
#           'lng': -96.80598397303409}],
#         'distance': 2133,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8845 Gary Burns Dr #150',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-589a532caf5c141e6cca4711-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52e90254498eaa4c89365594',
#        'name': 'Chick-fil-A',
#        'location': {'address': '8875 Preston Rd',
#         'lat': 33.149256,
#         'lng': -96.805104,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.149256,
#           'lng': -96.805104}],
#         'distance': 2077,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8875 Preston Rd',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52e90254498eaa4c89365594-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c02acee39d476b08efc2ea7',
#        'name': 'Frisco Mercantile',
#        'location': {'address': '8992 Preston Rd',
#         'crossStreet': 'Main',
#         'lat': 33.15140971433344,
#         'lng': -96.80234358579402,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15140971433344,
#           'lng': -96.80234358579402}],
#         'distance': 1727,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8992 Preston Rd (Main)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116951735',
#          'name': 'Antique Shop',
#          'pluralName': 'Antique Shops',
#          'shortName': 'Antiques',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c02acee39d476b08efc2ea7-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7853aef964a520abc52ee3',
#        'name': 'Frisco Commons',
#        'location': {'address': '8000 McKinney Rd',
#         'crossStreet': 'McKinney Road & North County Road',
#         'lat': 33.153425655796255,
#         'lng': -96.81393362705032,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.153425655796255,
#           'lng': -96.81393362705032}],
#         'distance': 2462,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8000 McKinney Rd (McKinney Road & North County Road)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7853aef964a520abc52ee3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '568c2dee498ea54f151e460b',
#        'name': "Jersey Mike's Subs",
#        'location': {'address': '7410 Preston Rd',
#         'crossStreet': 'Rolater',
#         'lat': 33.139852,
#         'lng': -96.802977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.139852,
#           'lng': -96.802977}],
#         'distance': 2852,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['7410 Preston Rd (Rolater)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '503150',
#         'url': 'https://www.grubhub.com/restaurant/jersey-mikes-subs-7410-preston-rd-ste-129-frisco/503150?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=503150',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-568c2dee498ea54f151e460b-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514a4113e4b0dd976e2585c6',
#        'name': 'Hope Park',
#        'location': {'address': '8000 McKinney Rd',
#         'lat': 33.15378312342159,
#         'lng': -96.81357214208845,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15378312342159,
#           'lng': -96.81357214208845}],
#         'distance': 2414,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8000 McKinney Rd',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514a4113e4b0dd976e2585c6-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c895258055315b20513271',
#        'name': 'Frisco Gun Club',
#        'location': {'address': '6565 Eldorado Pkwy',
#         'crossStreet': 'Tollway at Eldorado',
#         'lat': 33.174174803558586,
#         'lng': -96.82813574943313,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.174174803558586,
#           'lng': -96.82813574943313}],
#         'distance': 3743,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6565 Eldorado Pkwy (Tollway at Eldorado)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a11',
#          'name': 'Gun Range',
#          'pluralName': 'Gun Ranges',
#          'shortName': 'Gun Range',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/gun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '72267247'}},
#       'referralId': 'e-0-50c895258055315b20513271-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a6d2bd4f964a520a3d21fe3',
#        'name': "Babe's Chicken Dinner House",
#        'location': {'address': '6475 Page Rd',
#         'crossStreet': 'at John W Elliott Dr',
#         'lat': 33.14903143006786,
#         'lng': -96.83044639312995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.14903143006786,
#           'lng': -96.83044639312995}],
#         'distance': 4066,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6475 Page Rd (at John W Elliott Dr)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a6d2bd4f964a520a3d21fe3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aabe50ff964a520be5a20e3',
#        'name': '5th Street Patio Cafe',
#        'location': {'address': '8621 5th St',
#         'lat': 33.14781296825269,
#         'lng': -96.82479743603565,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.14781296825269,
#           'lng': -96.82479743603565}],
#         'distance': 3647,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8621 5th St',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aabe50ff964a520be5a20e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50843c7ce4b0ec60c638d20f',
#        'name': 'Simply Thai Bistro',
#        'location': {'address': '6842 Main St #101',
#         'lat': 33.15102777034824,
#         'lng': -96.82581832468233,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15102777034824,
#           'lng': -96.82581832468233}],
#         'distance': 3582,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6842 Main St #101',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50843c7ce4b0ec60c638d20f-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc9e549cc8cd13a3f5fbccf',
#        'name': 'Frisco Athletic Center',
#        'location': {'address': '5828 Nancy Jane Ln',
#         'crossStreet': 'Preston',
#         'lat': 33.12636945002513,
#         'lng': -96.80058372728422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.12636945002513,
#           'lng': -96.80058372728422}],
#         'distance': 4205,
#         'postalCode': '75035',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5828 Nancy Jane Ln (Preston)',
#          'Frisco, TX 75035',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc9e549cc8cd13a3f5fbccf-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b15502df964a5200db023e3',
#        'name': 'Toyota Stadium',
#        'location': {'address': '9200 World Cup Way',
#         'crossStreet': 'at Main & Frisco Sts',
#         'lat': 33.15460240129273,
#         'lng': -96.83544799557855,
#         'distance': 4322,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9200 World Cup Way (at Main & Frisco Sts)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d188941735',
#          'name': 'Soccer Stadium',
#          'pluralName': 'Soccer Stadiums',
#          'shortName': 'Soccer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '32682910'}},
#       'referralId': 'e-0-4b15502df964a5200db023e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6b9ddbf964a520b9122ce3',
#        'name': 'Frisco Public Library',
#        'location': {'address': '6101 Frisco Square Blvd',
#         'lat': 33.15018204719045,
#         'lng': -96.83420925447962,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15018204719045,
#           'lng': -96.83420925447962}],
#         'distance': 4347,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6101 Frisco Square Blvd',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d12f941735',
#          'name': 'Library',
#          'pluralName': 'Libraries',
#          'shortName': 'Library',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33512466'}},
#       'referralId': 'e-0-4b6b9ddbf964a520b9122ce3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6beef37d8b2c711b10c31e',
#        'name': 'Costco Wholesale',
#        'location': {'address': '11220 Dallas Pkwy',
#         'crossStreet': 'at Eldorado Pkwy',
#         'lat': 33.17179069614749,
#         'lng': -96.83732496633725,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.17179069614749,
#           'lng': -96.83732496633725}],
#         'distance': 4496,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11220 Dallas Pkwy (at Eldorado Pkwy)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '52e816a6bcbc57f1066b7a54',
#          'name': 'Warehouse Store',
#          'pluralName': 'Warehouse Stores',
#          'shortName': 'Warehouse Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e6beef37d8b2c711b10c31e-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5852bdfc11742042659616b7',
#        'name': 'Starbucks',
#        'location': {'address': '5722 Eldorado Parkway',
#         'lat': 33.175515661692124,
#         'lng': -96.83690177562717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.175515661692124,
#           'lng': -96.83690177562717}],
#         'distance': 4565,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5722 Eldorado Parkway',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5852bdfc11742042659616b7-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57f69208498e064cc2dca6a7',
#        'name': 'Frisco Rail Yard',
#        'location': {'address': '9040 1st St',
#         'lat': 33.1521987257479,
#         'lng': -96.82747674970412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.1521987257479,
#           'lng': -96.82747674970412}],
#         'distance': 3681,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9040 1st St',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57f69208498e064cc2dca6a7-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4e41b0e4b0577d81b03477',
#        'name': 'En Fuego Tobacco Shop',
#        'location': {'address': '6190 Frisco Square Blvd',
#         'lat': 33.15126384542201,
#         'lng': -96.83395329648663,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15126384542201,
#           'lng': -96.83395329648663}],
#         'distance': 4286,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6190 Frisco Square Blvd',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d123951735',
#          'name': 'Smoke Shop',
#          'pluralName': 'Smoke Shops',
#          'shortName': 'Smoke Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f4e41b0e4b0577d81b03477-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5302684a498ec9cb3261aeee',
#        'name': "Stan's Main Street",
#        'location': {'address': '7210 Main St',
#         'crossStreet': 'W. Main St & 7th Street',
#         'lat': 33.15024630213067,
#         'lng': -96.82132694339991,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15024630213067,
#           'lng': -96.82132694339991}],
#         'distance': 3236,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['7210 Main St (W. Main St & 7th Street)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5302684a498ec9cb3261aeee-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac8c902f964a52090bc20e3',
#        'name': "Rudy's Country Store and Bar-B-Q",
#        'location': {'address': '9828 Dallas Pkwy',
#         'crossStreet': 'Technology Dr',
#         'lat': 33.15988458325843,
#         'lng': -96.83920383453369,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15988458325843,
#           'lng': -96.83920383453369}],
#         'distance': 4581,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9828 Dallas Pkwy (Technology Dr)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac8c902f964a52090bc20e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51e6ec798bbd274dcb6e7897',
#        'name': 'Freebirds World Burrito',
#        'location': {'address': '5170 Main Street, Ste. 900',
#         'lat': 33.153359194948,
#         'lng': -96.84175997972488,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.153359194948,
#           'lng': -96.84175997972488}],
#         'distance': 4927,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5170 Main Street, Ste. 900',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51e6ec798bbd274dcb6e7897-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec2c020b8f7a3b7f969fec9',
#        'name': 'Nothing Bundt Cakes',
#        'location': {'address': '8837 Lebanon Rd Ste 650',
#         'lat': 33.12133509393889,
#         'lng': -96.80740450322213,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.12133509393889,
#           'lng': -96.80740450322213}],
#         'distance': 4921,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8837 Lebanon Rd Ste 650',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec2c020b8f7a3b7f969fec9-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527be37211d2138f2849daf4',
#        'name': 'QuikTrip',
#        'location': {'address': '5530 Eldorado Pkwy',
#         'crossStreet': 'Dallas Tollway',
#         'lat': 33.175527239779576,
#         'lng': -96.83857204120075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.175527239779576,
#           'lng': -96.83857204120075}],
#         'distance': 4714,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5530 Eldorado Pkwy (Dallas Tollway)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-527be37211d2138f2849daf4-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be4318dbcef2d7f1e2e02e5',
#        'name': 'Chick-fil-A',
#        'location': {'address': '5211 Eldorado Pkwy',
#         'lat': 33.174482,
#         'lng': -96.841201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.174482,
#           'lng': -96.841201}],
#         'distance': 4918,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5211 Eldorado Pkwy',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be4318dbcef2d7f1e2e02e5-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7c7de6f964a520a1962fe3',
#        'name': 'Sprouts Farmers Market',
#        'location': {'address': '5190 Preston Rd',
#         'crossStreet': 'at Lebanon Rd',
#         'lat': 33.12168193604114,
#         'lng': -96.80276602506643,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.12168193604114,
#           'lng': -96.80276602506643}],
#         'distance': 4760,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5190 Preston Rd (at Lebanon Rd)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '88023396'}},
#       'referralId': 'e-0-4b7c7de6f964a520a1962fe3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d86063899b78cfa110ddb1f',
#        'name': 'The Depot Cafe',
#        'location': {'address': '6733 Main St',
#         'crossStreet': '3rd street',
#         'lat': 33.15087425799501,
#         'lng': -96.82652641420997,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15087425799501,
#           'lng': -96.82652641420997}],
#         'distance': 3650,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6733 Main St (3rd street)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d86063899b78cfa110ddb1f-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b65ef01f964a5204f092be3',
#        'name': 'Market Street',
#        'location': {'address': '11999 Dallas Pkwy',
#         'crossStreet': 'at Eldorado Parkway',
#         'lat': 33.176908,
#         'lng': -96.843093,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.176908,
#           'lng': -96.843093}],
#         'distance': 5162,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11999 Dallas Pkwy (at Eldorado Parkway)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b65ef01f964a5204f092be3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '576b2938cd10f350e1b33561',
#        'name': '@nerdvana.coffee+shop',
#        'location': {'address': '5757 Main St #111',
#         'crossStreet': 'World Cup Way',
#         'lat': 33.152331351514604,
#         'lng': -96.8367846084929,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.152331351514604,
#           'lng': -96.8367846084929}],
#         'distance': 4505,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5757 Main St #111 (World Cup Way)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-576b2938cd10f350e1b33561-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c75b662ff1fb60c0422f7a7',
#        'name': 'FC Dallas Soccer Fields',
#        'location': {'lat': 33.15691839374224,
#         'lng': -96.83651578742497,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15691839374224,
#           'lng': -96.83651578742497}],
#         'distance': 4371,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Frisco, TX 75034', 'United States']},
#        'categories': [{'id': '4cce455aebf7b749d5e191f5',
#          'name': 'Soccer Field',
#          'pluralName': 'Soccer Fields',
#          'shortName': 'Soccer Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c75b662ff1fb60c0422f7a7-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf9aecf4a67c928774c27cf',
#        'name': 'FieldhouseUSA',
#        'location': {'address': '6155 Sports Village Rd',
#         'lat': 33.16151642987147,
#         'lng': -96.82990509653234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.16151642987147,
#           'lng': -96.82990509653234}],
#         'distance': 3705,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6155 Sports Village Rd',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e1941735',
#          'name': 'Basketball Court',
#          'pluralName': 'Basketball Courts',
#          'shortName': 'Basketball Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/basketballcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf9aecf4a67c928774c27cf-29'}]}]}}

# %% [markdown]
# Multiple categories

# %%
radius = 8000
categories = '4f4533814b9074f6e4fb0107,52e81612bcbc57f1066b7a45,4f4532974b9074f6e4fb0104'
#categories = '4f4533814b9074f6e4fb0107'
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT,categories)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0ICBHEHTFNB1KOUD5TI3Z14DZUD1R5LXFXGL4F3SMNFDZRQ5&client_secret=SGBN541VKULWFT2PKKVVL3EEV01GTYX1TQZJGW5HQ41MHRCL&ll=33.16313,-96.790193&v=20180604&radius=8000&limit=30&categoryId=4f4533814b9074f6e4fb0107,52e81612bcbc57f1066b7a45,4f4532974b9074f6e4fb0104'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7d9edef594df76b65b0da8'},
#  'response': {'venues': [{'id': '4fd74d9be4b054e49f42d75b',
#     'name': "Children's Lighthouse Frisco (Panther Creek)",
#     'location': {'address': '10660 Eldorado Parkway',
#      'lat': 33.175078,
#      'lng': -96.787373,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.175078,
#        'lng': -96.787373}],
#      'distance': 1355,
#      'postalCode': '75035',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['10660 Eldorado Parkway',
#       'Frisco, TX 75035',
#       'United States']},
#     'categories': [{'id': '4f4532974b9074f6e4fb0104',
#       'name': 'Daycare',
#       'pluralName': 'Daycares',
#       'shortName': 'Daycare',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '501bcd6de4b0d030d72436a6',
#     'name': 'Joyous Montessori McKinney',
#     'location': {'address': '6800 Bountiful Grove Dr.',
#      'lat': 33.155974,
#      'lng': -96.707425,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.155974,
#        'lng': -96.707425}],
#      'distance': 7754,
#      'postalCode': '75070',
#      'cc': 'US',
#      'city': 'McKinney',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['6800 Bountiful Grove Dr.',
#       'McKinney, TX 75070',
#       'United States']},
#     'categories': [{'id': '4f4532974b9074f6e4fb0104',
#       'name': 'Daycare',
#       'pluralName': 'Daycares',
#       'shortName': 'Daycare',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '73492456'},
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4c5ac9d104f9be9ab690f260',
#     'name': 'FISD Early Childhood School',
#     'location': {'lat': 33.15063525411252,
#      'lng': -96.7935771526685,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.15063525411252,
#        'lng': -96.7935771526685}],
#      'distance': 1426,
#      'postalCode': '75035',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Frisco, TX 75035', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4bb2587335f0c9b6a326bb83',
#     'name': 'Musical Arts Schoolhouse',
#     'location': {'address': '9255 Preston Rd',
#      'crossStreet': 'Main Street',
#      'lat': 33.154768,
#      'lng': -96.80531169999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.154768,
#        'lng': -96.80531169999999}],
#      'distance': 1688,
#      'postalCode': '75033',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['9255 Preston Rd (Main Street)',
#       'Frisco, TX 75033',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '91459457'},
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4d7e150b564b8cfa218eea64',
#     'name': 'Kids R Kids',
#     'location': {'address': '9070 Westridge',
#      'crossStreet': 'at Custer Rd.',
#      'lat': 33.18956928536393,
#      'lng': -96.73403708228064,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.18956928536393,
#        'lng': -96.73403708228064}],
#      'distance': 6003,
#      'postalCode': '75070',
#      'cc': 'US',
#      'city': 'McKinney',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['9070 Westridge (at Custer Rd.)',
#       'McKinney, TX 75070',
#       'United States']},
#     'categories': [{'id': '4f4533814b9074f6e4fb0107',
#       'name': 'Nursery School',
#       'pluralName': 'Nursery Schools',
#       'shortName': 'Nursery School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4d59a22756f2b60c38347b2f',
#     'name': 'Preston Kiddie Kollege',
#     'location': {'address': '4438 Legendary Dr',
#      'lat': 33.115345,
#      'lng': -96.809276,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.115345,
#        'lng': -96.809276}],
#      'distance': 5608,
#      'postalCode': '75034',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['4438 Legendary Dr',
#       'Frisco, TX 75034',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4d62efe6a7f3721eedd5d1ae',
#     'name': 'Kiddin Around',
#     'location': {'address': '9377 Lebanon Rd',
#      'lat': 33.1188142938367,
#      'lng': -96.80205136142598,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.1188142938367,
#        'lng': -96.80205136142598}],
#      'distance': 5055,
#      'postalCode': '75035',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['9377 Lebanon Rd',
#       'Frisco, TX 75035',
#       'United States']},
#     'categories': [{'id': '4f4532974b9074f6e4fb0104',
#       'name': 'Daycare',
#       'pluralName': 'Daycares',
#       'shortName': 'Daycare',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '53bfd8da498e4731c123db19',
#     'name': 'Canine Republic',
#     'location': {'lat': 33.09392477512618,
#      'lng': -96.8008259783463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.09392477512618,
#        'lng': -96.8008259783463}],
#      'distance': 7767,
#      'cc': 'US',
#      'city': 'Plano',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Plano, TX', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '56f36788498eafb8f672e618',
#     'name': 'Primrose School of Frisco at Main and Teel',
#     'location': {'address': '9166 Teel Pkwy',
#      'lat': 33.1545404,
#      'lng': -96.8631907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.1545404,
#        'lng': -96.8631907}],
#      'distance': 6869,
#      'postalCode': '75033',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['9166 Teel Pkwy',
#       'Frisco, TX 75033',
#       'United States']},
#     'categories': [{'id': '4f4532974b9074f6e4fb0104',
#       'name': 'Daycare',
#       'pluralName': 'Daycares',
#       'shortName': 'Daycare',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '54064045498ef5279ce4aae7',
#     'name': "Kids 'R' Kids Learning Academy of Legacy West",
#     'location': {'address': '5365 Lebanon Rd',
#      'lat': 33.115,
#      'lng': -96.84116,
#      'labeledLatLngs': [{'label': 'display', 'lat': 33.115, 'lng': -96.84116}],
#      'distance': 7160,
#      'postalCode': '75034',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['5365 Lebanon Rd',
#       'Frisco, TX 75034',
#       'United States']},
#     'categories': [{'id': '4f4532974b9074f6e4fb0104',
#       'name': 'Daycare',
#       'pluralName': 'Daycares',
#       'shortName': 'Daycare',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '134591874'},
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '5999c25acf72a014e4315957',
#     'name': 'Alpha Montessori House',
#     'location': {'address': '14275 Rolater Rd',
#      'lat': 33.137009,
#      'lng': -96.753341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.137009,
#        'lng': -96.753341}],
#      'distance': 4500,
#      'postalCode': '75035',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['14275 Rolater Rd',
#       'Frisco, TX 75035',
#       'United States']},
#     'categories': [{'id': '4f4533814b9074f6e4fb0107',
#       'name': 'Nursery School',
#       'pluralName': 'Nursery Schools',
#       'shortName': 'Nursery School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '526b0576498eadb29f1e020c',
#     'name': 'Castle Montessori Frisco',
#     'location': {'lat': 33.121782,
#      'lng': -96.808743,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.121782,
#        'lng': -96.808743}],
#      'distance': 4916,
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Frisco, TX', 'United States']},
#     'categories': [{'id': '4f4533814b9074f6e4fb0107',
#       'name': 'Nursery School',
#       'pluralName': 'Nursery Schools',
#       'shortName': 'Nursery School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4c66dc62f7a80f4731409f7a',
#     'name': 'Kumon Math and Reading Center of Plano - Four Corners',
#     'location': {'address': '10185 Custer Road, Suite #200',
#      'lat': 33.118045,
#      'lng': -96.7339056,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.118045,
#        'lng': -96.7339056}],
#      'distance': 7260,
#      'postalCode': '75025',
#      'cc': 'US',
#      'city': 'Plano',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['10185 Custer Road, Suite #200',
#       'Plano, TX 75025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4c9a04ae78ffa09310986875',
#     'name': 'Creme de la Creme',
#     'location': {'address': '9375 Legacy Dr',
#      'lat': 33.15624159705615,
#      'lng': -96.84834641659633,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.15624159705615,
#        'lng': -96.84834641659633}],
#      'distance': 5473,
#      'postalCode': '75033',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['9375 Legacy Dr',
#       'Frisco, TX 75033',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '50a3f703e4b0d94cd8abc7a3',
#     'name': 'Crosspoint Clubhouse',
#     'location': {'lat': 33.18214484422355,
#      'lng': -96.7144408005149,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.18214484422355,
#        'lng': -96.7144408005149}],
#      'distance': 7368,
#      'postalCode': '75070',
#      'cc': 'US',
#      'city': 'McKinney',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['McKinney, TX 75070', 'United States']},
#     'categories': [{'id': '4f4533814b9074f6e4fb0107',
#       'name': 'Nursery School',
#       'pluralName': 'Nursery Schools',
#       'shortName': 'Nursery School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '5a29b3eea795bd62e4b239aa',
#     'name': "Children's Lighthouse McKinney",
#     'location': {'address': '7900 Stacy Rd',
#      'lat': 33.15235347911573,
#      'lng': -96.7183743215121,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.15235347911573,
#        'lng': -96.7183743215121}],
#      'distance': 6799,
#      'postalCode': '75070',
#      'cc': 'US',
#      'city': 'McKinney',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['7900 Stacy Rd',
#       'McKinney, TX 75070',
#       'United States']},
#     'categories': [{'id': '4f4532974b9074f6e4fb0104',
#       'name': 'Daycare',
#       'pluralName': 'Daycares',
#       'shortName': 'Daycare',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4e67affbfa76f38efb39ca7d',
#     'name': "Kids 'R' Kids Learning Academy of West Frisco",
#     'location': {'address': '2660 Main St',
#      'crossStreet': 'at Teel Pkwy',
#      'lat': 33.154471,
#      'lng': -96.86724199999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.154471,
#        'lng': -96.86724199999999}],
#      'distance': 7244,
#      'postalCode': '75033',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['2660 Main St (at Teel Pkwy)',
#       'Frisco, TX 75033',
#       'United States']},
#     'categories': [{'id': '4f4532974b9074f6e4fb0104',
#       'name': 'Daycare',
#       'pluralName': 'Daycares',
#       'shortName': 'Daycare',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '134593670'},
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '50120efae4b0ad6ab1b637fb',
#     'name': 'Kumon Math and Reading Center of Frisco - Starwood',
#     'location': {'address': '5729 Lebanon Road, Suite #132',
#      'lat': 33.115503,
#      'lng': -96.837333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.115503,
#        'lng': -96.837333}],
#      'distance': 6885,
#      'postalCode': '75034',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['5729 Lebanon Road, Suite #132',
#       'Frisco, TX 75034',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4e40a67d6284809c9f3719b8',
#     'name': 'Daffodils preschool',
#     'location': {'address': '4901',
#      'lat': 33.15288692234101,
#      'lng': -96.724158725834,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.15288692234101,
#        'lng': -96.724158725834}],
#      'distance': 6258,
#      'postalCode': '75070',
#      'cc': 'US',
#      'city': 'McKinney',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['4901', 'McKinney, TX 75070', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '5328589c498ee2957fbdd9ed',
#     'name': 'Heritage Learning Academy',
#     'location': {'address': '2755 Timber Ridge Dr',
#      'crossStreet': 'Teel Parkway',
#      'lat': 33.1299133300781,
#      'lng': -96.8666610717773,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.1299133300781,
#        'lng': -96.8666610717773}],
#      'distance': 8029,
#      'postalCode': '75034',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['2755 Timber Ridge Dr (Teel Parkway)',
#       'Frisco, TX 75034',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '81718905'},
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '56c33acacd105e2638b91904',
#     'name': 'spanish schoolhouse',
#     'location': {'lat': 33.128882,
#      'lng': -96.812039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.128882,
#        'lng': -96.812039}],
#      'distance': 4322,
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Frisco, TX', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '5421b96c498e353abf128ce7',
#     'name': 'Kumon Math and Reading Center of Mckinney - Westridge',
#     'location': {'address': '1550 S. Custer Road',
#      'lat': 33.18985560938314,
#      'lng': -96.73356369137764,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.18985560938314,
#        'lng': -96.73356369137764}],
#      'distance': 6057,
#      'postalCode': '75070',
#      'cc': 'US',
#      'city': 'McKinney',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['1550 S. Custer Road',
#       'McKinney, TX 75070',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4c7549c766be6dcbaff1bf0f',
#     'name': 'Primrose School of Plano at Deerfield',
#     'location': {'address': '4100 Hedgcoxe Road',
#      'crossStreet': 'Coit',
#      'lat': 33.085286,
#      'lng': -96.773975,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.085286,
#        'lng': -96.773975}],
#      'distance': 8796,
#      'postalCode': '75024',
#      'cc': 'US',
#      'city': 'Plano',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['4100 Hedgcoxe Road (Coit)',
#       'Plano, TX 75024',
#       'United States']},
#     'categories': [{'id': '4f4532974b9074f6e4fb0104',
#       'name': 'Daycare',
#       'pluralName': 'Daycares',
#       'shortName': 'Daycare',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False},
#    {'id': '4c81418e88e6199cde51b1d4',
#     'name': 'Starwood Montessori',
#     'location': {'address': '6600 Lebanon Rd',
#      'lat': 33.1214,
#      'lng': -96.82706,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.1214,
#        'lng': -96.82706}],
#      'distance': 5778,
#      'postalCode': '75034',
#      'cc': 'US',
#      'city': 'Frisco',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['6600 Lebanon Rd',
#       'Frisco, TX 75034',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551736542',
#     'hasPerk': False}],
#   'confident': False}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.columns
# Out:
# Index(['categories', 'hasPerk', 'id', 'location.address', 'location.cc',
#        'location.city', 'location.country', 'location.crossStreet',
#        'location.distance', 'location.formattedAddress',
#        'location.labeledLatLngs', 'location.lat', 'location.lng',
#        'location.postalCode', 'location.state', 'name', 'referralId',
#        'venuePage.id'],
#       dtype='object')

# %%
dataframe = dataframe[dataframe['location.postalCode']=='75035']
dataframe.shape
# Out:
# (4, 18)

# %% [markdown]
# # Read data about all zipcodes in 100 miles of current locations

# %%
csv_path = 'C:/Users/anand/OneDrive/Python/Coursera_ML/Data/ZipCodes within 100 miles.csv'
Zips_in_100 = pd.read_csv(csv_path)

# %%
Zips_in_100.rename(columns={'Zip Code': 'Zipcode'},inplace=True)
Zips_in_100.head()
# Out:
#    Zipcode           City  County
# 0    73030      Davis, OK  Murray
# 1    73032  Dougherty, OK  Murray
# 2    73086    Sulphur, OK  Murray
# 3    73401    Ardmore, OK  Carter
# 4    73402    Ardmore, OK  Carter

# %% [markdown]
# # Read location data for all zipcodes in US

# %%
location_csv = 'C:/Users/anand/OneDrive/Python/Coursera_ML/Data/ZipCodes to Lat_Long.csv'
Zips_geocodes = pd.read_csv(location_csv)

# %%
# Out:
#        Zip Code  Latitude  Longitude
# 34228     75035   33.1377   -96.7524

# %%
Zips_geocodes.rename(columns={'Zip Code': 'Zipcode'},inplace=True)
Zips_geocodes.head()
# Out:
#    Zipcode  Latitude  Longitude
# 0    99553   54.1430  -165.7854
# 1    99571   55.1858  -162.7211
# 2    99583   54.8542  -163.4113
# 3    99612   55.0628  -162.3056
# 4    99661   55.3192  -160.4914

# %%
Zips_geocodes.shape
# Out:
# (41467, 3)

# %%
Zips_in_100.shape
# Out:
# (689, 3)

# %%
Zips_with_geocodes = Zips_in_100.merge(Zips_geocodes)
Zips_with_geocodes.head()
# Out:
#    Zipcode           City  County  Latitude  Longitude
# 0    73030      Davis, OK  Murray   34.4953   -97.1084
# 1    73032  Dougherty, OK  Murray   34.4020   -97.0510
# 2    73086    Sulphur, OK  Murray   34.5116   -96.9797
# 3    73401    Ardmore, OK  Carter   34.1566   -97.1792
# 4    73402    Ardmore, OK  Carter   34.2889   -97.2481

# %%
def getNearbyVenues(names, latitudes, longitudes, city, radius=8000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
           
        radius = 8000
        categories = '4f4533814b9074f6e4fb0107,52e81612bcbc57f1066b7a45,4f4532974b9074f6e4fb0104'
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT,categories)
          
        print(city)
        # make the GET request
        results = requests.get(url).json()["response"]['venues']
       ## return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            city,
            v['name'],
            v['location']['lat'], 
            v['location']['lng'],
            v['location']["city"]
            ) for v in results])

   
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Zipcode', 
                  'Zipcode Latitude', 
                  'Zipcode Longitude',
                  'Zipcode City'
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude',
                  'Venue City']
    
#     nearby_venues = nearby_venues[nearby_venues['location.postalCode']=='75035']
    
    return(nearby_venues)

# %% [markdown]
# # Call foursquare to get all preschools in a zip code and export to a csv file

# %%
Zips_with_geocodes = Zips_with_geocodes[Zips_with_geocodes['Zipcode']==75035]
Zips_with_geocodes.head()
preschool_venues = getNearbyVenues(names=Zips_with_geocodes['Zipcode'],
                                   latitudes=Zips_with_geocodes['Latitude'],
                                   longitudes=Zips_with_geocodes['Longitude'],
                                   city=Zips_with_geocodes['City']
                                  )
preschool_venues.head()
# Out:
# 92    Frisco, TX
# Name: City, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-273-8e423248d403> in <module>
#       4                                    latitudes=Zips_with_geocodes['Latitude'],
#       5                                    longitudes=Zips_with_geocodes['Longitude'],
# ----> 6                                    city=Zips_with_geocodes['City']
#       7                                   )
#       8 preschool_venues.head()
#
# <ipython-input-272-b7be1c6f182a> in getNearbyVenues(names, latitudes, longitudes, city, radius)
#      32                   'Venue Latitude',
#      33                   'Venue Longitude',
# ---> 34                   'Venue City']
#      35
#      36 #     nearby_venues = nearby_venues[nearby_venues['location.postalCode']=='75035']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5068         try:
#    5069             object.__getattribute__(self, name)
# -> 5070             return object.__setattr__(self, name, value)
#    5071         except AttributeError:
#    5072             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     627
#     628     def _set_axis(self, axis, labels):
# --> 629         self._data.set_axis(axis, labels)
#     630         self._clear_item_cache()
#     631
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 7 elements

# %%
preschool_venues.to_csv('zipcodes_with_preschools.csv')
